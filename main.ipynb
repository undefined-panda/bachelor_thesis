# %%
import synthetic_data_generation
from nn_train_tests import *

# %%
synthetic_data_generation.main(dim_list=[9, 32], img_list=[1000, 1000])

# %%
dataset = np.load('9x9_synthesized_data.npz')
epochs = 20
lr = 0.01
bs = 32
test_1(dataset, epochs, lr, bs, False, True)
# Out:
# ------------------------------------------------------------------------------------------
# --------------- Test 1: default filters vs fixed binary custom filters (9x9) ---------------
# ------------------------------------------------------------------------------------------
# Training models: 100%|██████████| 5/5 [00:25<00:00,  5.06s/it]
