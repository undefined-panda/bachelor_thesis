# %%
import sys
import os
import numpy as np

notebook_dir = os.path.dirname(os.path.abspath("__file__"))
project_dir = os.path.join(notebook_dir, '..')
sys.path.insert(0, os.path.abspath(project_dir))

from src import filter_tests, synthetic_data_generation

# %%
synthetic_data_generation.main(dim_list=[32], img_list=[2000], file_name="my_data_v1")
# Out:
# Dataset for 32x32 already exists. Do you want to recreate it? [Y/N]
# Recreating 32x32 dataset
#
# Dataset saved in 'c:\Users\jadta\Documents\Studium\Bachelor\BachelorArbeit\programming\bachelor_thesis\data\32x32_my_data_v1.npz'

# %%
from src.helper_functions import print_data
dataset = np.load("data/32x32_my_data_v1.npz")
labels = dataset["labels"]
for file in dataset.files:
    if file=="labels":
        break
    data = dataset[file]
    print_data(data, labels)

epochs = 20
lr = 0.0001
bs = 16
# Out:
# Label 0: 1000
# Label 1: 1000
# Label 0: 1000
# Label 1: 1000
# Label 0: 1000
# Label 1: 1000
# Label 0: 1000
# Label 1: 1000
# Label 0: 1000
# Label 1: 1000

# %%
filter_tests.test_1(dataset, epochs, lr, bs, False, True)

# %%
filter_tests.test_2(dataset, epochs, lr, bs, False, True)

# %%
filter_tests.test_3(dataset, epochs, lr, bs, False, True)

# %%
dataset_name = "32x32_my_data_v3"
filter_tests.test_4(dataset, epochs, lr, bs, dataset_name, False, True)
