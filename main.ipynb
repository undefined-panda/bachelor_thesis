# %%
import sys
import os
import numpy as np

notebook_dir = os.path.dirname(os.path.abspath("__file__"))
project_dir = os.path.join(notebook_dir, '..')
sys.path.insert(0, os.path.abspath(project_dir))

from src import filter_tests, synthetic_data_generation
from src.helper_functions import print_data

# %%
# synthetic_data_generation.main(dim_list=[32], img_list=[2000], file_name="my_data_v1")

# dataset = np.load("data/32x32_my_data_v1.npz")
# labels = dataset["labels"]
# for file in dataset.files:
#     if file=="labels":
#         break
#     data = dataset[file]
#     print_data(data, labels)

# %%
folder_path = 'data'

for file_name in os.listdir(folder_path):
    print(file_name)
    dataset = np.load(folder_path+"/"+file_name)
    labels = dataset["labels"]
    for file in dataset.files:
        if file=="labels":
            continue
        print(file)
        data = dataset[file]
        print_data(data, labels)
    
    print("\n\n")
# Out:
# 32x32_ml_ppa_data_binary.npz
# n_10
# Label 0: 500
# Label 1: 500
# n_20
# Label 0: 500
# Label 1: 500
# n_30
# Label 0: 500
# Label 1: 500
# n_40
# Label 0: 500
# Label 1: 500
# 32x32_ml_ppa_data_multi.npz
# n_10
# Label 0: 500
# Label 1: 500
# Label 2: 500
# Label 3: 500
# n_20
# Label 0: 500
# Label 1: 500
# Label 2: 500
# Label 3: 500
# n_30
# Label 0: 500
# Label 1: 500
# Label 2: 500
# Label 3: 500
# n_40
# Label 0: 500
# Label 1: 500
# Label 2: 500
# Label 3: 500
# 32x32_my_data_v1.npz
# n_00
# Label 0: 1000
# Label 1: 1000
# n_70
# Label 0: 1000
# Label 1: 1000
# n_80
# Label 0: 1000
# Label 1: 1000
# n_90
# Label 0: 1000
# Label 1: 1000
# n_100
# Label 0: 1000
# Label 1: 1000
# 32x32_my_data_v2.npz
# n_00
# Label 0: 1000
# Label 1: 1000
# n_70
# Label 0: 1000
# Label 1: 1000
# n_80
# Label 0: 1000
# Label 1: 1000
# n_90
# Label 0: 1000
# Label 1: 1000
# n_100
# Label 0: 1000
# Label 1: 1000
# 32x32_my_data_v3.npz
# n_00
# Label 0: 1000
# Label 1: 1000
# n_70
# Label 0: 1000
# ...

# %%
dataset = np.load("data/32x32_my_data_v1.npz")

epochs = 20
lr = 0.001
bs = 16
learn_plot = False
graph_plot = True

filter_tests.test_1(dataset, epochs, lr, bs, learn_plot, graph_plot)
filter_tests.test_2(dataset, epochs, lr, bs, learn_plot, graph_plot)
filter_tests.test_3(dataset, epochs, lr, bs, learn_plot, graph_plot)
filter_tests.test_4(dataset, epochs, lr, bs, learn_plot, graph_plot)
# Out:
# ------------------------------------------------------------------------------------------
# ------------- Testing: default filters vs fixed binary custom filters (32x32) --------------
# ------------------------------------------------------------------------------------------
# Training models: 100%|██████████| 5/5 [01:13<00:00, 14.61s/it]
# ------------------------------------------------------------------------------------------
# ---------- Testing: default filters vs changing binary custom filters v1 (32x32) -----------
# ------------------------------------------------------------------------------------------
# Training models: 100%|██████████| 5/5 [01:18<00:00, 15.67s/it]
# ------------------------------------------------------------------------------------------
# ---------- Testing: default filters vs changing binary custom filters v2 (32x32) -----------
# ------------------------------------------------------------------------------------------
# ...

# %%
dataset = np.load("data/32x32_my_data_v2.npz")

epochs = 20
lr = 0.001
bs = 16
learn_plot = False
graph_plot = True

filter_tests.test_1(dataset, epochs, lr, bs, learn_plot, graph_plot)
filter_tests.test_2(dataset, epochs, lr, bs, learn_plot, graph_plot)
filter_tests.test_3(dataset, epochs, lr, bs, learn_plot, graph_plot)
filter_tests.test_4(dataset, epochs, lr, bs, learn_plot, graph_plot)
# Out:
# ------------------------------------------------------------------------------------------
# ------------- Testing: default filters vs fixed binary custom filters (32x32) --------------
# ------------------------------------------------------------------------------------------
# Training models: 100%|██████████| 6/6 [01:07<00:00, 11.27s/it]
# ------------------------------------------------------------------------------------------
# ---------- Testing: default filters vs changing binary custom filters v1 (32x32) -----------
# ------------------------------------------------------------------------------------------
# Training models: 100%|██████████| 6/6 [00:54<00:00,  9.14s/it]
# ------------------------------------------------------------------------------------------
# ---------- Testing: default filters vs changing binary custom filters v2 (32x32) -----------
# ------------------------------------------------------------------------------------------
# ...

# %%
dataset = np.load("data/32x32_my_data_v3.npz")

epochs = 20
lr = 0.001
bs = 16
learn_plot = False
graph_plot = True

filter_tests.test_1(dataset, epochs, lr, bs, learn_plot, graph_plot)
filter_tests.test_2(dataset, epochs, lr, bs, learn_plot, graph_plot)
filter_tests.test_3(dataset, epochs, lr, bs, learn_plot, graph_plot)
filter_tests.test_4(dataset, epochs, lr, bs, learn_plot, graph_plot)
# Out:
# ------------------------------------------------------------------------------------------
# ------------- Testing: default filters vs fixed binary custom filters (32x32) --------------
# ------------------------------------------------------------------------------------------
# Training models: 100%|██████████| 5/5 [01:11<00:00, 14.35s/it]
# ------------------------------------------------------------------------------------------
# ---------- Testing: default filters vs changing binary custom filters v1 (32x32) -----------
# ------------------------------------------------------------------------------------------
# Training models: 100%|██████████| 5/5 [01:11<00:00, 14.22s/it]
# ------------------------------------------------------------------------------------------
# ---------- Testing: default filters vs changing binary custom filters v2 (32x32) -----------
# ------------------------------------------------------------------------------------------
# ...

# %%
dataset = np.load("data/32x32_ml_ppa_data_binary.npz")

epochs = 20
lr = 0.001
bs = 16
learn_plot = False
graph_plot = True

filter_tests.test_1(dataset, epochs, lr, bs, learn_plot, graph_plot)
filter_tests.test_2(dataset, epochs, lr, bs, learn_plot, graph_plot)
filter_tests.test_3(dataset, epochs, lr, bs, learn_plot, graph_plot)
filter_tests.test_4(dataset, epochs, lr, bs, learn_plot, graph_plot)
# Out:
# ------------------------------------------------------------------------------------------
# ------------- Testing: default filters vs fixed binary custom filters (32x32) --------------
# ------------------------------------------------------------------------------------------
# ...
# Training models: 100%|██████████| 5/5 [00:33<00:00,  6.70s/it]
# ------------------------------------------------------------------------------------------
# ---------- Testing: default filters vs changing binary custom filters v1 (32x32) -----------
# ------------------------------------------------------------------------------------------
# Training models: 100%|██████████| 5/5 [00:32<00:00,  6.54s/it]
# ------------------------------------------------------------------------------------------
# ---------- Testing: default filters vs changing binary custom filters v2 (32x32) -----------
# ------------------------------------------------------------------------------------------
# ...

# %%
dataset = np.load("data/32x32_ml_ppa_data_multi.npz")

epochs = 20
lr = 0.001
bs = 16
learn_plot = False
graph_plot = True

filter_tests.test_1(dataset, epochs, lr, bs, learn_plot, graph_plot)
filter_tests.test_2(dataset, epochs, lr, bs, learn_plot, graph_plot)
filter_tests.test_3(dataset, epochs, lr, bs, learn_plot, graph_plot)
filter_tests.test_4(dataset, epochs, lr, bs, learn_plot, graph_plot)
# Out:
# ------------------------------------------------------------------------------------------
# ------------- Testing: default filters vs fixed binary custom filters (32x32) --------------
# ------------------------------------------------------------------------------------------
# Training models: 100%|██████████| 5/5 [01:13<00:00, 14.76s/it]
# ------------------------------------------------------------------------------------------
# ---------- Testing: default filters vs changing binary custom filters v1 (32x32) -----------
# ------------------------------------------------------------------------------------------
# Training models: 100%|██████████| 5/5 [01:13<00:00, 14.70s/it]
# ------------------------------------------------------------------------------------------
# ---------- Testing: default filters vs changing binary custom filters v2 (32x32) -----------
# ------------------------------------------------------------------------------------------
# ...
