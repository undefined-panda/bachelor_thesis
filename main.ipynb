# %%
import src.synthetic_data_generation
from src.nn_train_tests import *

# %%
src.synthetic_data_generation.main(dim_list=[9, 32], img_list=[1000, 1000])
# Out:
# here c:\Users\jadta\Documents\Studium\Bachelor\BachelorArbeit\programming\bachelor_thesis\data
# Dataset for 9x9 already exists. Do you want to recreate it? [Y/N]
# Creating 9x9 dataset
#
# Dataset saved in 'c:\Users\jadta\Documents\Studium\Bachelor\BachelorArbeit\programming\bachelor_thesis\data\9x9_synthesized_data.npz'
#
# here c:\Users\jadta\Documents\Studium\Bachelor\BachelorArbeit\programming\bachelor_thesis\data
# Dataset for 32x32 already exists. Do you want to recreate it? [Y/N]
# Creating 32x32 dataset
#
# Dataset saved in 'c:\Users\jadta\Documents\Studium\Bachelor\BachelorArbeit\programming\bachelor_thesis\data\32x32_synthesized_data.npz'

# %%
dataset = np.load('data/9x9_synthesized_data.npz')
epochs = 20
lr = 0.01
bs = 32
test_1(dataset, epochs, lr, bs, False, True)
# Out:
# ------------------------------------------------------------------------------------------
# --------------- Test 1: default filters vs fixed binary custom filters (9x9) ---------------
# ------------------------------------------------------------------------------------------
# Training models: 100%|██████████| 5/5 [00:25<00:00,  5.17s/it]
